# %%
import requests
import logging
import os
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
Save_dir="G:\Practice( data\Scraper\img"
if not os.path.exists(Save_dir):
    os.makedirs(Save_dir)

# %%
query = "elon musk"
url = f"https://www.google.com/search?sca_esv=2f61a0c390a4d1ff&rlz=1C1ONGR_enIN1082IN1082&sxsrf=ACQVn08WrH_MvXdQXLLFpniZ-UMI01qqIg:1714557597762&q={query}&tbm=isch&source=lnms&sa=X&ved=2ahUKEwiz177kmOyFAxUqaPUHHZ9hCrsQ0pQJegQICxAB&biw=1366&bih=599&dpr=1"

# %%
response = requests.get("https://www.google.com/search?sca_esv=2f61a0c390a4d1ff&rlz=1C1ONGR_enIN1082IN1082&sxsrf=ACQVn08WrH_MvXdQXLLFpniZ-UMI01qqIg:1714557597762&q={query}&tbm=isch&source=lnms&sa=X&ved=2ahUKEwiz177kmOyFAxUqaPUHHZ9hCrsQ0pQJegQICxAB&biw=1366&bih=599&dpr=1")

# %%
response
# Out:
# <Response [200]>

# %%
BeautifulSoup(response.content)
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
soup=BeautifulSoup(response.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %% [markdown]
# and now collecting images

# %%
soup.find_all("img")
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTblXeV8ppnzpNcSQYIANzn6rcbCCfR-eNJM-Xo-v8jZ-neVmSUhIlbn2sGZ7M&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3ymkdcLRAhGbBJeWqiCH1f2bjDHSqU2i-mAhJ4mYXjfpq_X-sXblHiNrM5w&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRqCBr7wnAh08aMOHlUh5eQSDQJqcUZBGsZ3Gws9bLv8yr6dSExK5OsU1BcGQ&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgeKwO0k8vQKqDlBTMFNvvAWWNQdmuOOfr_jHjMCWTyflevZ1EhMe5Cyi-NA&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBUYGt6CCvSkjgAD8rClK1-PxSoWqnjDd_WeMO_xUmeRQ6OK8QbAJvP7NRXQ&amp;s"/>,
# ...

# %%
image_tags=soup.find_all("img")

# %%
del image_tags[0]

# %%
image_tags
# Out:
# [<img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTblXeV8ppnzpNcSQYIANzn6rcbCCfR-eNJM-Xo-v8jZ-neVmSUhIlbn2sGZ7M&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3ymkdcLRAhGbBJeWqiCH1f2bjDHSqU2i-mAhJ4mYXjfpq_X-sXblHiNrM5w&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRqCBr7wnAh08aMOHlUh5eQSDQJqcUZBGsZ3Gws9bLv8yr6dSExK5OsU1BcGQ&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgeKwO0k8vQKqDlBTMFNvvAWWNQdmuOOfr_jHjMCWTyflevZ1EhMe5Cyi-NA&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBUYGt6CCvSkjgAD8rClK1-PxSoWqnjDd_WeMO_xUmeRQ6OK8QbAJvP7NRXQ&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQYKxWg0on7dTkytcyqJHvHJCwYZoAPKjbrnsaNlfRAHlk7E1y_KfVXbioR4Q&amp;s"/>,
# ...

# %% [markdown]
# how many images are there

# %%
len(image_tags)
# Out:
# 20

# %% [markdown]
# download images

# %%
for i in image_tags:
    print(i['src'])
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTblXeV8ppnzpNcSQYIANzn6rcbCCfR-eNJM-Xo-v8jZ-neVmSUhIlbn2sGZ7M&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3ymkdcLRAhGbBJeWqiCH1f2bjDHSqU2i-mAhJ4mYXjfpq_X-sXblHiNrM5w&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRqCBr7wnAh08aMOHlUh5eQSDQJqcUZBGsZ3Gws9bLv8yr6dSExK5OsU1BcGQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgeKwO0k8vQKqDlBTMFNvvAWWNQdmuOOfr_jHjMCWTyflevZ1EhMe5Cyi-NA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBUYGt6CCvSkjgAD8rClK1-PxSoWqnjDd_WeMO_xUmeRQ6OK8QbAJvP7NRXQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQYKxWg0on7dTkytcyqJHvHJCwYZoAPKjbrnsaNlfRAHlk7E1y_KfVXbioR4Q&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAm0Yd2HugQd2FefPhjlwvqlqZ2smr2BOpGNfVkv0C4rbl1gzgJ5Re5P-kGfU&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLYMMzXgLOjysMHPwQuvwP-rlctC0WTm46uX7JPW0N3HgpMboaO57Ze8cj5KY&s
# ...

# %%
requests.get("https://www.google.com/search?sca_esv=2f61a0c390a4d1ff&rlz=1C1ONGR_enIN1082IN1082&sxsrf=ACQVn08WrH_MvXdQXLLFpniZ-UMI01qqIg:1714557597762&q={query}&tbm=isch&source=lnms&sa=X&ved=2ahUKEwiz177kmOyFAxUqaPUHHZ9hCrsQ0pQJegQICxAB&biw=1366&bih=599&dpr=1").content
# Out:
# b'<!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml" lang="en-IN"><head><meta content="application/xhtml+xml; charset=UTF-8" http-equiv="Content-Type"/><meta content="no-cache" name="Cache-Control"/><title>{query} - Google Search</title><style>a{text-decoration:none;color:inherit}a:hover{text-decoration:underline}a img{border:0}body{font-family:arial,sans-serif;padding:8px;margin:0 auto;max-width:700px;min-width:240px;}.FbhRzb{border-left:thin solid #dadce0;border-right:thin solid #dadce0;border-top:thin solid #dadce0;height:40px;overflow:hidden}.n692Zd{margin-bottom:10px}.cvifge{height:40px;border-spacing:0}.QvGUP{height:40px;padding:0 8px 0 8px;vertical-align:top}.O4cRJf{height:40px;width:100%;padding:0;padding-right:16px}.O1ePr{height:40px;padding:0;vertical-align:top}.kgJEQe{height:36px;width:98px;vertical-align:top;margin-top:4px}.lXLRf{vertical-align:top}.MhzMZd{border:0;verti
# ...

# %%
for i in image_tags:
    print(i['src'])
